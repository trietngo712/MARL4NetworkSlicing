# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

root_path = os.path.abspath("../..")
sys.path.append(root_path)

from algorithm.MADDPG import MADDPGTrainer, MADDPGTester
from network_env.network_env_v4 import NetworkEnvV4

# %% [markdown]
# ### Directories

# %%
RESOURCE_PATH = "experiments/experiment_3/configs/resource_config.json"
LOG_PATH = "experiments/experiment_3/results"

# %% [markdown]
# ### Configurations

# %%
frames_per_batch = 100
n_iter = 200
min_replay_size = 1000
memory_size = 200000
n_optimizer_steps = 100
train_batch_size = 128
actor_lr = 1e-4
critic_lr = 1e-4
max_grad_norm = 1.0
gamma = 0.99
polyak_tau = 0.005

critic_configs = {
        "num_cells":256,
        "depth":2,
        "share_parameter": True,
        "centralized_critic": True
    }

actor_configs = {
        "num_cells":256,
        "depth":2,
        "share_parameter":True
    }

MAX_QUEUE_LENGTH = 5 #5 times capacity
PENALTY = -1
ALPHA = 1.0
BETA = 100.0

# %% [markdown]
# ### Experiment 1
#
# - Single slice
# - Constant Demand = 0.5
# - (lambda, rho) = (0.5,0.5), (0.1,0.9), (0.9,0.1)

# %%
n_agent = 1
test_demand = 0.5
latency_pref = [0.5, 0.1, 0.9]
energy_pref = [0.5, 0.9, 0.1]

# %%
for idx, (lambda_, rho_) in enumerate(zip(latency_pref, energy_pref)):
    
    log_path = os.path.join(LOG_PATH,f"1.{idx}")
    
    train_env = NetworkEnvV4(
        n_slices=n_agent,
        resource_path=RESOURCE_PATH,
        traffic_path=None,
        log_path= os.path.join(log_path,'train'),
        test_demand=test_demand,
        max_queue_length=MAX_QUEUE_LENGTH,
        penalty_reward=PENALTY,
        latency_preference=[lambda_],
        energy_preference=[rho_]
    )

    test_env = NetworkEnvV4(
        n_slices=n_agent,
        resource_path=RESOURCE_PATH,
        traffic_path=None,
        log_path=os.path.join(log_path,'test'),
        test_demand=test_demand,
        max_queue_length=MAX_QUEUE_LENGTH,
        penalty_reward=PENALTY,
        latency_preference=[lambda_],
        energy_preference=[rho_]
    )

    trainer = MADDPGTrainer(
        environment=train_env,
        n_agent=n_agent,
        frames_per_batch=frames_per_batch,
        n_iter=n_iter,
        min_replay_size=min_replay_size,
        memory_size=memory_size,
        n_optimizer_steps= n_optimizer_steps,
        train_batch_size=train_batch_size,
        actor_lr=actor_lr,
        critic_lr=critic_lr,
        max_grad_norm=max_grad_norm,
        polyak_tau=polyak_tau,
        gamma=gamma,
        critic_configs=critic_configs,
        actor_configs=actor_configs,
        save_path=log_path
    )

    tester = MADDPGTester(
        environment=train_env,
        n_agent=n_agent,
        frames_per_batch=frames_per_batch,
        n_iter=n_iter,
        min_replay_size=min_replay_size,
        memory_size=memory_size,
        n_optimizer_steps= n_optimizer_steps,
        train_batch_size=train_batch_size,
        actor_lr=actor_lr,
        critic_lr=critic_lr,
        max_grad_norm=max_grad_norm,
        polyak_tau=polyak_tau,
        gamma=gamma,
        critic_configs=critic_configs,
        actor_configs=actor_configs,
        load_path=log_path
    )
    
    trainer.train()
    tester.test()
    train_env
# Out:
# --- Reset 0 ---
# --- Reset 0 ---

# %%
trainer.train()
# Out:
# --- Reset 0 ---
# 2026-06-04 15:19:09,016 [torchrl][INFO]    Initialized LazyMemmapStorage with torch.Size([200000]) shape [END]
# --- Reset 188 ---
# --- Reset 327 ---
# --- Reset 822 ---
# --- Reset 927 ---
# --- Reset 1041 ---
# /home/tngo/MARL4NetworkSlicing/algorithm/MADDPG.py:72: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   self.env = PettingZooWrapper(env = environment, use_mask = True, categorical_actions=False, device = self.device)
#   0%|          | 0/200 [01:16<?, ?it/s]
# --- Reset 1310 ---
# --- Reset 1323 ---
# --- Reset 1335 ---
# --- Reset 1349 ---
# --- Reset 1363 ---
# --- Reset 1376 ---
# --- Reset 1389 ---
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 trainer.train()
#
# File ~/MARL4NetworkSlicing/algorithm/MADDPG.py:90, in train(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/MARL4NetworkSlicing/.venv/lib/python3.12/site-packages/torch/serialization.py:849, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     846 _check_save_filelike(f)
#     848 if _use_new_zipfile_serialization:
# --> 849     with _open_zipfile_writer(f) as opened_zipfile:
#     850         _save(
#     851             obj,
#     852             opened_zipfile,
#    (...)    855             _disable_byteorder_record,
#     856         )
#     857         return
#
# File ~/MARL4NetworkSlicing/.venv/lib/python3.12/site-packages/torch/serialization.py:716, in _open_zipfile_writer(name_or_buffer)
#     714 else:
#     715     container = _open_zipfile_writer_buffer
# --> 716 return container(name_or_buffer)
#
# File ~/MARL4NetworkSlicing/.venv/lib/python3.12/site-packages/torch/serialization.py:687, in _open_zipfile_writer_file.__init__(self, name)
#     685     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     686 else:
# --> 687     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory experiments/experiment_3/results/1.1 does not exist.
