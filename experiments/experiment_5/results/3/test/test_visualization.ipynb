# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pathlib import Path

# %%
demand_path = "../../data/test/slice_0_demand.csv"
action_path = "./slice_0/action.csv"
